# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam

# %% [markdown]
# Завантажимо датасет __fashion_mnist__ та розділимо його на навчальний та тренувальний:

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)
# 60000 train set
# 10000 test set

# %% [markdown]
# Візуалізуємо зображення з нашого датасету:

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# Нормалізуємо дані датасету, побудуємо модель нашої нейромережі та проведемо її навчання:

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    Dense(288, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 288)               147744
#
#  dense_3 (Dense)             (None, 10)                2890
#
# =================================================================
# Total params: 815210 (3.11 MB)
# Trainable params: 815210 (3.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Проведемо навчання нашої моделі:

# %%
LEARNING_RATE = 0.0001
EPOCHS = 20
BATCH_SIZE=96

model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 10s 17ms/step - loss: 0.6309 - accuracy: 0.7945 - val_loss: 0.4514 - val_accuracy: 0.8371
# Epoch 2/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.4118 - accuracy: 0.8562 - val_loss: 0.4022 - val_accuracy: 0.8574
# Epoch 3/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.3678 - accuracy: 0.8695 - val_loss: 0.3885 - val_accuracy: 0.8602
# Epoch 4/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.3376 - accuracy: 0.8801 - val_loss: 0.3433 - val_accuracy: 0.8777
# Epoch 5/20
# 500/500 [==============================] - 8s 17ms/step - loss: 0.3164 - accuracy: 0.8865 - val_loss: 0.3612 - val_accuracy: 0.8692
# Epoch 6/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.2970 - accuracy: 0.8927 - val_loss: 0.3337 - val_accuracy: 0.8803
# Epoch 7/20
# 500/500 [==============================] - 8s 17ms/step - loss: 0.2816 - accuracy: 0.8973 - val_loss: 0.3246 - val_accuracy: 0.8836
# Epoch 8/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.2667 - accuracy: 0.9035 - val_loss: 0.3462 - val_accuracy: 0.8764
# Epoch 9/20
# 500/500 [==============================] - 8s 16ms/step - loss: 0.2574 - accuracy: 0.9075 - val_loss: 0.3135 - val_accuracy: 0.8844
# Epoch 10/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.2433 - accuracy: 0.9119 - val_loss: 0.3061 - val_accuracy: 0.8898
# Epoch 11/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.2323 - accuracy: 0.9162 - val_loss: 0.3187 - val_accuracy: 0.8876
# Epoch 12/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.2232 - accuracy: 0.9188 - val_loss: 0.3076 - val_accuracy: 0.8888
# Epoch 13/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.2143 - accuracy: 0.9221 - val_loss: 0.3059 - val_accuracy: 0.8928
# Epoch 14/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.2047 - accuracy: 0.9254 - val_loss: 0.3047 - val_accuracy: 0.8929
# Epoch 15/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1970 - accuracy: 0.9295 - val_loss: 0.3037 - val_accuracy: 0.8941
# Epoch 16/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1885 - accuracy: 0.9310 - val_loss: 0.3038 - val_accuracy: 0.8933
# Epoch 17/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1808 - accuracy: 0.9353 - val_loss: 0.2959 - val_accuracy: 0.8950
# Epoch 18/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1723 - accuracy: 0.9376 - val_loss: 0.3077 - val_accuracy: 0.8938
# Epoch 19/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1654 - accuracy: 0.9399 - val_loss: 0.3118 - val_accuracy: 0.8943
# Epoch 20/20
# 500/500 [==============================] - 9s 17ms/step - loss: 0.1579 - accuracy: 0.9424 - val_loss: 0.3078 - val_accuracy: 0.8945

# %% [markdown]
# Побудуємо графіки кривих навчання:

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# Проведемо оцінку точності роботи нашої моделі на тренувальному та тестовому наборах даних:

# %%
train_loss, train_accuracy = model.evaluate(x_train, y_train)
print(f"Train loss: {train_loss:.4f}")
print(f"Train accuracy: {train_accuracy:.4f}")

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1747 - accuracy: 0.9392
# Train loss: 0.1747
# Train accuracy: 0.9392
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3334 - accuracy: 0.8910
# Test loss: 0.3334
# Test accuracy: 0.8910

# %% [markdown]
# Використаємо нашу модель для прогнозування на частині тестового датасету та візуалізуємо результати:

# %%
y_pred = model.predict(x_test)

figure = plt.figure(figsize=(10, 10))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=25, replace=False)):
    ax = figure.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
    
    ax.imshow(np.squeeze(x_test[index]), cmap=plt.cm.binary)
    predict_index = np.argmax(y_pred[index])
    true_index = y_test[index]
    
    ax.set_xlabel('{} ({})'.format(class_names[predict_index], 
                                  class_names[true_index]),
                                  color=('green' if predict_index == true_index else 'red'))
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

predicted_labels = np.argmax(y_pred, axis=1)

conf_matrix = confusion_matrix(y_test, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
